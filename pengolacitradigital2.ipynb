# %% [markdown]
# **READ IMAGE**

# %%
import cv2

# %%
img = cv2.imread("/content/drive/MyDrive/images.jpeg")
type(img)
# Out:
# numpy.ndarray

# %%
cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4202464600.py in <cell line: 0>()
# ----> 1 cv2.imshow("Image", img)
#       2 cv2.waitKey(0)
#       3 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined

# %%
img = cv2.imread("/content/drive/MyDrive/images.jpeg")
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 254 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %% [markdown]
# **IMAGE MATRIX**

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
type(img.shape)
# Out:
# tuple

# %%
h, w, c = img.shape
h, w, c
# Out:
# (225, 225, 3)

# %%
h*w
# Out:
# 50625

# %%
img.nbytes
# Out:
# 151875

# %%
img.nbytes/1024
# Out:
# 148.3154296875

# %%
import os

# %%
os.path.getsize("/content/drive/MyDrive/images.jpeg")
# Out:
# 4554

# %%
img.ndim
# Out:
# 3

# %%
img.min()
# Out:
# np.uint8(0)

# %%
img.max()
# Out:
# np.uint8(255)

# %%
img.size
# Out:
# 151875

# %%
h*w*c
# Out:
# 151875

# %% [markdown]
# **ACCESS IMAGE CHANNEL**

# %%
img[:,:,0].shape #layer 0 (blue)
# Out:
# (225, 225)

# %%
img[:,:,1].shape #layer 1 (green)
# Out:
# (225, 225)

# %%
img[:,:,2].shape #layer 2 (red)
# Out:
# (225, 225)

# %%
img[0,0]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
(B, G, R) = img[200,200]
print("R=%d, G=%d, B=%d" % (R, G, B))
# Out:
# R=234, G=236, B=248

# %%
import cv2

# %%
img = cv2.imread("/content/drive/MyDrive/download (8).png")
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[204, 206, 206],
#         [  4,   4,   4],
#         [  0,   0,   0],
#         ...,
#         [  0,   0,   1],
#         [  4,   4,   4],
#         [205, 205, 205]],
#
#        [[215, 217, 217],
#         [ 10,  10,  10],
#         [  0,   0,   0],
#         ...,
#         [  0,   0,   1],
#         [  1,   1,   1],
#         [180, 180, 180]],
#
#        [[210, 212, 212],
#         [  4,   4,   4],
#         [  0,   0,   0],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img_rgb = img[:, :, 1]
plt.imshow(img_rgb)

# %%
img_red = img[:,:, 2]
plt.imshow(img_red, cmap="gray")

# %%
img_green = img[:, :, 0]
plt.imshow(img_green, cmap="gray")

# %%
img_blue = img[:, :, 0]
plt.imshow(img_blue, cmap="grey")

# %% [markdown]
# **SAVE IMAGE**

# %%
cv2.imwrite('/content/drive/MyDrive/download (8).png',img)
# Out:
# True

# %%
cap = cv2.VideoCapture(0)
ret, frame = cap.read()

if ret :
  cv2.imwrite("/content/drive/MyDrive/download (8).png")
